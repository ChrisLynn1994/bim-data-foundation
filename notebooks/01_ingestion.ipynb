# %% [markdown]
# # 1. Load CSV

# %%
import sys
sys.executable

import pandas as pd

df = pd.read_csv("../data/raw/schema_v0_export_host_linked.csv")

# %% [markdown]
# # 2. Head (first look)

# %%
df.head()

# %% [markdown]
# # 3. DataFrame info

# %%
df.info()

# %% [markdown]
# # 4. Describe (numeric sanity check)

# %%
df.describe()

# %% [markdown]
# # 5. Initial observations (markdown)

# %% [markdown]
# ## Initial Observations
#
# - Many elements have missing geometric attributes
# - Symbolic and view-related elements are present
# - Height/width populated mainly for structural categories
# - Units appear consistent but not yet verified

# %% [markdown]
# # 6. Null Count Per Column

# %%
df.isna().sum()

# %% [markdown]
# # 7. Missing Data Percentage

# %%
(df.isna().mean()*100).round(2)

# %% [markdown]
# # 8. Unique Value Count Per Column

# %%
df.nunique(dropna=True)

# %% [markdown]
# # Day 5 Data Quantity Snapshot

# %% [markdown]
# ## Day 5 – Data Quality Snapshot Notes
#
# - Significant missingness in geometric columns (height, width, volume)
# - Material and level are sparsely populated
# - Many rows appear to represent symbolic or annotation-like elements
# - No unexpected columns or corrupted dtypes observed
